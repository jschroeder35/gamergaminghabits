# %%
import pickle

# %%
with open('raw_data/valid_ids.txt', 'r') as file:
    previds=file.read().splitlines()

# %%
len(previds)
# Out:
# 471

# %%
with open ('./raw_data/maria_test1/game_data_0.pkl', 'rb') as fp:
    loaded_data = pickle.load(fp)
loaded_data
# Out:
# 41

# %%
with open ('./raw_data/initial_test_josh/game_data_3.pkl', 'rb') as fp:
    loaded_data = pickle.load(fp)
len(loaded_data)
# Out:
# 7

# %%
previds1=[]

for i in range(len(loaded_data)):
    previds1.append(loaded_data[i][0])
    
previds1
# Out:
# ['76561198038301770',
#  '76561198055686432',
#  '76561198073576311',
#  '76561198062162858',
#  '76561198064357787',
#  '76561198073241990',
#  '76561198098895535']

# %%
with open('raw_data/valid_ids.txt', 'a') as file:
    for id in previds1:
        file.write(id+"\n")

# %%
type(previds)
# Out:
# list

# %%
previds
# Out:
# ['76561198078022827',
#  '76561198062057850',
#  '76561198069717244',
#  '76561198079073891',
#  '76561198073339847',
#  '76561198097426383',
#  '76561198089663699',
#  '76561198084324477',
#  '76561198067051402',
#  '76561198062670485',
#  '76561198072791933',
#  '76561198093741043',
#  '76561198087080039',
#  '76561198067028836',
#  '76561198063916610',
#  '76561198086517535',
#  '76561198091105414',
#  '76561198079598645',
#  '76561198066597742',
#  '76561198087269064',
#  '76561198066051445',
#  '76561198083148174',
#  '76561198076316444',
#  '76561198070894981',
#  '76561198097026377',
#  '76561198078945019',
#  '76561198074339685',
#  '76561198090574210',
#  '76561198070966169',
#  '76561198077538622',
#  '76561198074122481',
#  '76561198096915145',
#  '76561198097274577',
#  '76561198093478297',
#  '76561198096439217',
#  '76561198086755890',
#  '76561198082855621',
#  '76561198081654074',
#  '76561198068901269',
#  '76561198094191793',
#  '76561198071329284',
# ...

# %%
type(loaded_data)
# Out:
# list
