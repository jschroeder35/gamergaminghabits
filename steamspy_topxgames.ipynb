# %%
import steamspypi

data_request = dict()
data_request['request'] = 'top100owned'

data = steamspypi.download(data_request)

# %%
data
# Out:
# {'570': {'appid': 570,
#   'name': 'Dota 2',
#   'developer': 'Valve',
#   'publisher': 'Valve',
#   'score_rank': '',
#   'positive': 1637953,
#   'negative': 349272,
#   'userscore': 0,
#   'owners': '200,000,000 .. 500,000,000',
#   'average_forever': 39748,
#   'average_2weeks': 1365,
#   'median_forever': 1143,
#   'median_2weeks': 681,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 684957},
#  '1172470': {'appid': 1172470,
#   'name': 'Apex Legends',
#   'developer': 'Respawn Entertainment',
#   'publisher': 'Electronic Arts',
#   'score_rank': '',
#   'positive': 538237,
#   'negative': 119350,
#   'userscore': 0,
#   'owners': '50,000,000 .. 100,000,000',
#   'average_forever': 7498,
#   'average_2weeks': 777,
#   'median_forever': 754,
#   'median_2weeks': 332,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 381669},
#  '730': {'appid': 730,
#   'name': 'Counter-Strike: Global Offensive',
#   'developer': 'Valve, Hidden Path Entertainment',
#   'publisher': 'Valve',
#   'score_rank': '',
#   'positive': 6418930,
#   'negative': 817518,
#   'userscore': 0,
#   'owners': '50,000,000 .. 100,000,000',
#   'average_forever': 30298,
#   'average_2weeks': 864,
#   'median_forever': 6100,
#   'median_2weeks': 316,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 1280367},
#  '578080': {'appid': 578080,
#   'name': 'PUBG: BATTLEGROUNDS',
#   'developer': 'KRAFTON, Inc.',
#   'publisher': 'KRAFTON, Inc.',
#   'score_rank': '',
#   'positive': 1246449,
#   'negative': 932099,
#   'userscore': 0,
#   'owners': '50,000,000 .. 100,000,000',
#   'average_forever': 22417,
#   'average_2weeks': 750,
#   'median_forever': 6785,
#   'median_2weeks': 203,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 297421},
#  '1063730': {'appid': 1063730,
#   'name': 'New World',
#   'developer': 'Amazon Games',
#   'publisher': 'Amazon Games',
#   'score_rank': '',
#   'positive': 178477,
#   'negative': 76603,
#   'userscore': 0,
#   'owners': '50,000,000 .. 100,000,000',
#   'average_forever': 7653,
#   'average_2weeks': 925,
#   'median_forever': 3505,
#   'median_2weeks': 780,
#   'price': '1999',
#   'initialprice': '3999',
#   'discount': '50',
#   'ccu': 17484},
#  '440': {'appid': 440,
#   'name': 'Team Fortress 2',
#   'developer': 'Valve',
#   'publisher': 'Valve',
#   'score_rank': '',
#   'positive': 896100,
#   'negative': 59379,
#   'userscore': 0,
#   'owners': '50,000,000 .. 100,000,000',
#   'average_forever': 10432,
#   'average_2weeks': 850,
#   'median_forever': 386,
#   'median_2weeks': 115,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 88644},
#  '271590': {'appid': 271590,
#   'name': 'Grand Theft Auto V',
#   'developer': 'Rockstar North',
#   'publisher': 'Rockstar Games',
#   'score_rank': '',
#   'positive': 1340898,
#   'negative': 220545,
#   'userscore': 0,
#   'owners': '50,000,000 .. 100,000,000',
#   'average_forever': 12932,
#   'average_2weeks': 639,
#   'median_forever': 5825,
#   'median_2weeks': 152,
#   'price': '2998',
#   'initialprice': '2998',
#   'discount': '0',
#   'ccu': 133518},
#  '1599340': {'appid': 1599340,
#   'name': 'Lost Ark',
#   'developer': 'Smilegate RPG',
#   'publisher': 'Amazon Games',
#   'score_rank': '',
#   'positive': 138308,
#   'negative': 54380,
#   'userscore': 0,
#   'owners': '50,000,000 .. 100,000,000',
#   'average_forever': 4039,
#   'average_2weeks': 530,
#   'median_forever': 796,
#   'median_2weeks': 551,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 53028},
#  '550': {'appid': 550,
#   'name': 'Left 4 Dead 2',
#   'developer': 'Valve',
#   'publisher': 'Valve',
#   'score_rank': '',
#   'positive': 719239,
#   'negative': 18279,
#   'userscore': 0,
#   'owners': '20,000,000 .. 50,000,000',
#   'average_forever': 2207,
#   'average_2weeks': 138,
#   'median_forever': 523,
#   'median_2weeks': 68,
#   'price': '999',
#   'initialprice': '999',
#   'discount': '0',
#   'ccu': 32133},
#  '304930': {'appid': 304930,
#   'name': 'Unturned',
#   'developer': 'Smartly Dressed Games',
#   'publisher': 'Smartly Dressed Games',
#   'score_rank': '',
#   'positive': 468872,
#   'negative': 43471,
#   'userscore': 0,
#   'owners': '20,000,000 .. 50,000,000',
#   'average_forever': 6932,
#   'average_2weeks': 3187,
#   'median_forever': 314,
#   'median_2weeks': 425,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 64274},
#  '252490': {'appid': 252490,
#   'name': 'Rust',
#   'developer': 'Facepunch Studios',
#   'publisher': 'Facepunch Studios',
#   'score_rank': '',
#   'positive': 802615,
#   'negative': 120321,
#   'userscore': 0,
#   'owners': '20,000,000 .. 50,000,000',
#   'average_forever': 22330,
#   'average_2weeks': 1523,
#   'median_forever': 3148,
#   'median_2weeks': 612,
#   'price': '3999',
#   'initialprice': '3999',
#   'discount': '0',
#   'ccu': 122609},
#  '230410': {'appid': 230410,
#   'name': 'Warframe',
#   'developer': 'Digital Extremes',
#   'publisher': 'Digital Extremes',
#   'score_rank': '',
#   'positive': 465176,
#   'negative': 73069,
#   'userscore': 0,
#   'owners': '20,000,000 .. 50,000,000',
#   'average_forever': 8862,
#   'average_2weeks': 1550,
#   'median_forever': 392,
#   'median_2weeks': 940,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 69426},
#  '105600': {'appid': 105600,
#   'name': 'Terraria',
#   'developer': 'Re-Logic',
#   'publisher': 'Re-Logic',
#   'score_rank': '',
#   'positive': 1106373,
#   'negative': 25412,
#   'userscore': 0,
#   'owners': '20,000,000 .. 50,000,000',
#   'average_forever': 7319,
#   'average_2weeks': 517,
#   'median_forever': 2064,
#   'median_2weeks': 155,
#   'price': '999',
#   'initialprice': '999',
#   'discount': '0',
#   'ccu': 44341},
#  '4000': {'appid': 4000,
#   'name': "Garry's Mod",
#   'developer': 'Facepunch Studios',
#   'publisher': 'Valve',
#   'score_rank': '',
#   'positive': 925945,
#   'negative': 31742,
#   'userscore': 0,
#   'owners': '20,000,000 .. 50,000,000',
#   'average_forever': 10441,
#   'average_2weeks': 688,
#   'median_forever': 1416,
#   'median_2weeks': 212,
#   'price': '999',
#   'initialprice': '999',
#   'discount': '0',
#   'ccu': 35226},
#  '1245620': {'appid': 1245620,
#   'name': 'ELDEN RING',
#   'developer': 'FromSoftware Inc.',
#   'publisher': 'FromSoftware Inc., Bandai Namco Entertainment',
#   'score_rank': '',
#   'positive': 619886,
#   'negative': 54409,
#   'userscore': 0,
#   'owners': '20,000,000 .. 50,000,000',
#   'average_forever': 5759,
#   'average_2weeks': 356,
#   'median_forever': 4689,
#   'median_2weeks': 128,
#   'price': '5999',
#   'initialprice': '5999',
#   'discount': '0',
#   'ccu': 34130},
#  '236390': {'appid': 236390,
#   'name': 'War Thunder',
#   'developer': 'Gaijin Entertainment',
#   'publisher': 'Gaijin Distribution KFT',
#   'score_rank': '',
#   'positive': 292441,
#   'negative': 221690,
#   'userscore': 0,
#   'owners': '20,000,000 .. 50,000,000',
#   'average_forever': 7457,
#   'average_2weeks': 1045,
#   'median_forever': 418,
#   'median_2weeks': 352,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 86195},
#  '291550': {'appid': 291550,
#   'name': 'Brawlhalla',
#   'developer': 'Blue Mammoth Games',
#   'publisher': 'Ubisoft',
#   'score_rank': '',
#   'positive': 270294,
#   'negative': 53240,
#   'userscore': 0,
#   'owners': '20,000,000 .. 50,000,000',
#   'average_forever': 2705,
#   'average_2weeks': 251,
#   'median_forever': 191,
#   'median_2weeks': 218,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 17736},
#  '359550': {'appid': 359550,
#   'name': "Tom Clancy's Rainbow Six Siege",
#   'developer': 'Ubisoft Montreal',
#   'publisher': 'Ubisoft',
#   'score_rank': '',
#   'positive': 982390,
#   'negative': 155038,
#   'userscore': 0,
#   'owners': '20,000,000 .. 50,000,000',
#   'average_forever': 13095,
#   'average_2weeks': 427,
#   'median_forever': 2442,
#   'median_2weeks': 203,
#   'price': '1999',
#   'initialprice': '1999',
#   'discount': '0',
#   'ccu': 54546},
#  '340': {'appid': 340,
#   'name': 'Half-Life 2: Lost Coast',
#   'developer': 'Valve',
#   'publisher': 'Valve',
#   'score_rank': '',
#   'positive': 10291,
#   'negative': 1304,
#   'userscore': 0,
#   'owners': '20,000,000 .. 50,000,000',
#   'average_forever': 48,
#   'average_2weeks': 0,
#   'median_forever': 22,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 17},
#  '431960': {'appid': 431960,
#   'name': 'Wallpaper Engine',
#   'developer': 'Wallpaper Engine Team',
#   'publisher': 'Wallpaper Engine Team',
#   'score_rank': '',
#   'positive': 639285,
#   'negative': 12320,
#   'userscore': 0,
#   'owners': '20,000,000 .. 50,000,000',
#   'average_forever': 3549,
#   'average_2weeks': 122,
#   'median_forever': 791,
#   'median_2weeks': 13,
#   'price': '399',
#   'initialprice': '399',
#   'discount': '0',
#   'ccu': 102152},
#  '1085660': {'appid': 1085660,
#   'name': 'Destiny 2',
#   'developer': 'Bungie',
#   'publisher': 'Bungie',
#   'score_rank': '',
#   'positive': 451243,
#   'negative': 92516,
#   'userscore': 0,
#   'owners': '20,000,000 .. 50,000,000',
#   'average_forever': 8846,
#   'average_2weeks': 1107,
#   'median_forever': 398,
#   'median_2weeks': 779,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 158060},
#  '945360': {'appid': 945360,
#   'name': 'Among Us',
#   'developer': 'Innersloth',
#   'publisher': 'Innersloth',
#   'score_rank': '',
#   'positive': 606740,
#   'negative': 54194,
#   'userscore': 0,
#   'owners': '20,000,000 .. 50,000,000',
#   'average_forever': 1241,
#   'average_2weeks': 204,
#   'median_forever': 678,
#   'median_2weeks': 54,
#   'price': '499',
#   'initialprice': '499',
#   'discount': '0',
#   'ccu': 5661},
#  '238960': {'appid': 238960,
#   'name': 'Path of Exile',
#   'developer': 'Grinding Gear Games',
#   'publisher': 'Grinding Gear Games',
#   'score_rank': '',
#   'positive': 177169,
#   'negative': 24341,
#   'userscore': 0,
#   'owners': '20,000,000 .. 50,000,000',
#   'average_forever': 10857,
#   'average_2weeks': 1720,
#   'median_forever': 446,
#   'median_2weeks': 646,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 34128},
#  '218620': {'appid': 218620,
#   'name': 'PAYDAY 2',
#   'developer': 'OVERKILL - a Starbreeze Studio.',
#   'publisher': 'Starbreeze Publishing AB',
#   'score_rank': '',
#   'positive': 555966,
#   'negative': 63818,
#   'userscore': 0,
#   'owners': '20,000,000 .. 50,000,000',
#   'average_forever': 5762,
#   'average_2weeks': 1182,
#   'median_forever': 550,
#   'median_2weeks': 207,
#   'price': '999',
#   'initialprice': '999',
#   'discount': '0',
#   'ccu': 20813},
#  '892970': {'appid': 892970,
#   'name': 'Valheim',
#   'developer': 'Iron Gate AB',
#   'publisher': 'Coffee Stain Publishing',
#   'score_rank': '',
#   'positive': 384398,
#   'negative': 20576,
#   'userscore': 0,
#   'owners': '20,000,000 .. 50,000,000',
#   'average_forever': 3543,
#   'average_2weeks': 955,
#   'median_forever': 1510,
#   'median_2weeks': 405,
#   'price': '1999',
#   'initialprice': '1999',
#   'discount': '0',
#   'ccu': 23797},
#  '901583': {'appid': 901583,
#   'name': 'Grand Theft Auto IV: Complete Edition',
#   'developer': 'Rockstar North, Rockstar Toronto',
#   'publisher': 'Rockstar Games',
#   'score_rank': '',
#   'positive': 100065,
#   'negative': 25840,
#   'userscore': 0,
#   'owners': '20,000,000 .. 50,000,000',
#   'average_forever': 0,
#   'average_2weeks': 0,
#   'median_forever': 0,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 0},
#  '1091500': {'appid': 1091500,
#   'name': 'Cyberpunk 2077',
#   'developer': 'CD PROJEKT RED',
#   'publisher': 'CD PROJEKT RED',
#   'score_rank': '',
#   'positive': 479784,
#   'negative': 133761,
#   'userscore': 0,
#   'owners': '20,000,000 .. 50,000,000',
#   'average_forever': 3692,
#   'average_2weeks': 304,
#   'median_forever': 2676,
#   'median_2weeks': 97,
#   'price': '5999',
#   'initialprice': '5999',
#   'discount': '0',
#   'ccu': 15602},
#  '1097150': {'appid': 1097150,
#   'name': 'Fall Guys: Ultimate Knockout',
#   'developer': 'Mediatonic',
#   'publisher': 'SmashGames',
#   'score_rank': '',
#   'positive': 385937,
#   'negative': 88825,
#   'userscore': 0,
#   'owners': '20,000,000 .. 50,000,000',
#   'average_forever': 1758,
#   'average_2weeks': 88,
#   'median_forever': 518,
#   'median_2weeks': 113,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 4048},
#  '242760': {'appid': 242760,
#   'name': 'The Forest',
#   'developer': 'Endnight Games Ltd',
#   'publisher': 'Endnight Games Ltd',
#   'score_rank': '',
#   'positive': 459083,
#   'negative': 21954,
#   'userscore': 0,
#   'owners': '20,000,000 .. 50,000,000',
#   'average_forever': 1719,
#   'average_2weeks': 141,
#   'median_forever': 801,
#   'median_2weeks': 80,
#   'price': '1999',
#   'initialprice': '1999',
#   'discount': '0',
#   'ccu': 5528},
#  '322330': {'appid': 322330,
#   'name': "Don't Starve Together",
#   'developer': 'Klei Entertainment',
#   'publisher': 'Klei Entertainment',
#   'score_rank': '',
#   'positive': 381223,
#   'negative': 15997,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 2304,
#   'average_2weeks': 363,
#   'median_forever': 548,
#   'median_2weeks': 162,
#   'price': '1499',
#   'initialprice': '1499',
#   'discount': '0',
#   'ccu': 50726},
#  '444090': {'appid': 444090,
#   'name': 'Paladins',
#   'developer': 'Evil Mojo Games',
#   'publisher': 'Hi-Rez Studios',
#   'score_rank': '',
#   'positive': 286929,
#   'negative': 49415,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 3157,
#   'average_2weeks': 535,
#   'median_forever': 465,
#   'median_2weeks': 371,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 9521},
#  '291480': {'appid': 291480,
#   'name': 'Warface',
#   'developer': 'MY.GAMES',
#   'publisher': 'MY.GAMES',
#   'score_rank': '',
#   'positive': 54852,
#   'negative': 26634,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 895,
#   'average_2weeks': 0,
#   'median_forever': 110,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 1543},
#  '346110': {'appid': 346110,
#   'name': 'ARK: Survival Evolved',
#   'developer': 'Studio Wildcard, Instinct Games, Efecto Studios, Virtual Basement LLC',
#   'publisher': 'Studio Wildcard',
#   'score_rank': '',
#   'positive': 522212,
#   'negative': 110058,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 13104,
#   'average_2weeks': 1194,
#   'median_forever': 880,
#   'median_2weeks': 454,
#   'price': '1999',
#   'initialprice': '1999',
#   'discount': '0',
#   'ccu': 63972},
#  '413150': {'appid': 413150,
#   'name': 'Stardew Valley',
#   'developer': 'ConcernedApe',
#   'publisher': 'ConcernedApe',
#   'score_rank': '',
#   'positive': 557524,
#   'negative': 10082,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 4185,
#   'average_2weeks': 637,
#   'median_forever': 1736,
#   'median_2weeks': 517,
#   'price': '1499',
#   'initialprice': '1499',
#   'discount': '0',
#   'ccu': 38156},
#  '49520': {'appid': 49520,
#   'name': 'Borderlands 2',
#   'developer': 'Gearbox Software, Aspyr (Mac), Aspyr (Linux)',
#   'publisher': '2K, Aspyr (Mac), Aspyr (Linux)',
#   'score_rank': '',
#   'positive': 256585,
#   'negative': 16978,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 3099,
#   'average_2weeks': 357,
#   'median_forever': 959,
#   'median_2weeks': 456,
#   'price': '499',
#   'initialprice': '1999',
#   'discount': '75',
#   'ccu': 3859},
#  '10': {'appid': 10,
#   'name': 'Counter-Strike',
#   'developer': 'Valve',
#   'publisher': 'Valve',
#   'score_rank': '',
#   'positive': 214191,
#   'negative': 5458,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 9825,
#   'average_2weeks': 392,
#   'median_forever': 143,
#   'median_2weeks': 500,
#   'price': '999',
#   'initialprice': '999',
#   'discount': '0',
#   'ccu': 11340},
#  '272060': {'appid': 272060,
#   'name': 'Serena',
#   'developer': 'Senscape',
#   'publisher': 'Senscape',
#   'score_rank': '',
#   'positive': 4881,
#   'negative': 1430,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 452,
#   'average_2weeks': 0,
#   'median_forever': 17,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 1},
#  '292030': {'appid': 292030,
#   'name': 'The Witcher 3: Wild Hunt',
#   'developer': 'CD PROJEKT RED',
#   'publisher': 'CD PROJEKT RED',
#   'score_rank': '',
#   'positive': 690737,
#   'negative': 29153,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 3554,
#   'average_2weeks': 279,
#   'median_forever': 927,
#   'median_2weeks': 97,
#   'price': '3999',
#   'initialprice': '3999',
#   'discount': '0',
#   'ccu': 16493},
#  '438100': {'appid': 438100,
#   'name': 'VRChat',
#   'developer': 'VRChat Inc.',
#   'publisher': 'VRChat Inc.',
#   'score_rank': '',
#   'positive': 141797,
#   'negative': 54092,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 3100,
#   'average_2weeks': 1071,
#   'median_forever': 113,
#   'median_2weeks': 290,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 33718},
#  '381210': {'appid': 381210,
#   'name': 'Dead by Daylight',
#   'developer': 'Behaviour Interactive Inc.',
#   'publisher': 'Behaviour Interactive Inc.',
#   'score_rank': '',
#   'positive': 532777,
#   'negative': 133624,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 9621,
#   'average_2weeks': 474,
#   'median_forever': 1126,
#   'median_2weeks': 244,
#   'price': '1999',
#   'initialprice': '1999',
#   'discount': '0',
#   'ccu': 45820},
#  '227940': {'appid': 227940,
#   'name': 'Heroes & Generals',
#   'developer': 'TLM Partners',
#   'publisher': 'TLM Partners',
#   'score_rank': '',
#   'positive': 95711,
#   'negative': 47330,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 1091,
#   'average_2weeks': 54,
#   'median_forever': 75,
#   'median_2weeks': 62,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 37},
#  '1240440': {'appid': 1240440,
#   'name': 'Halo Infinite',
#   'developer': '343 Industries',
#   'publisher': 'Xbox Game Studios',
#   'score_rank': '',
#   'positive': 111158,
#   'negative': 47311,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 1073,
#   'average_2weeks': 172,
#   'median_forever': 144,
#   'median_2weeks': 133,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 4536},
#  '227300': {'appid': 227300,
#   'name': 'Euro Truck Simulator 2',
#   'developer': 'SCS Software',
#   'publisher': 'SCS Software',
#   'score_rank': '',
#   'positive': 632149,
#   'negative': 16784,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 5768,
#   'average_2weeks': 339,
#   'median_forever': 1680,
#   'median_2weeks': 106,
#   'price': '1999',
#   'initialprice': '1999',
#   'discount': '0',
#   'ccu': 38123},
#  '252950': {'appid': 252950,
#   'name': 'Rocket League',
#   'developer': 'Psyonix LLC',
#   'publisher': 'Psyonix LLC',
#   'score_rank': '',
#   'positive': 502936,
#   'negative': 64474,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 16264,
#   'average_2weeks': 516,
#   'median_forever': 3026,
#   'median_2weeks': 193,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 25540},
#  '1468810': {'appid': 1468810,
#   'name': '鬼谷八荒 Tale of Immortal',
#   'developer': '鬼谷工作室',
#   'publisher': '鬼谷工作室, Lightning Games',
#   'score_rank': '',
#   'positive': 110740,
#   'negative': 105890,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 3866,
#   'average_2weeks': 690,
#   'median_forever': 2093,
#   'median_2weeks': 523,
#   'price': '1499',
#   'initialprice': '1999',
#   'discount': '25',
#   'ccu': 23764},
#  '620': {'appid': 620,
#   'name': 'Portal 2',
#   'developer': 'Valve',
#   'publisher': 'Valve',
#   'score_rank': '',
#   'positive': 339339,
#   'negative': 4257,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 891,
#   'average_2weeks': 170,
#   'median_forever': 522,
#   'median_2weeks': 138,
#   'price': '199',
#   'initialprice': '199',
#   'discount': '0',
#   'ccu': 2851},
#  '552990': {'appid': 552990,
#   'name': 'World of Warships',
#   'developer': 'Wargaming Group Limited',
#   'publisher': 'Wargaming Group Limited',
#   'score_rank': '',
#   'positive': 97675,
#   'negative': 23513,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 3541,
#   'average_2weeks': 1139,
#   'median_forever': 247,
#   'median_2weeks': 1212,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 9764},
#  '739630': {'appid': 739630,
#   'name': 'Phasmophobia',
#   'developer': 'Kinetic Games',
#   'publisher': 'Kinetic Games',
#   'score_rank': '',
#   'positive': 536978,
#   'negative': 18206,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 1727,
#   'average_2weeks': 231,
#   'median_forever': 824,
#   'median_2weeks': 98,
#   'price': '1399',
#   'initialprice': '1399',
#   'discount': '0',
#   'ccu': 14586},
#  '320': {'appid': 320,
#   'name': 'Half-Life 2: Deathmatch',
#   'developer': 'Valve',
#   'publisher': 'Valve',
#   'score_rank': '',
#   'positive': 10575,
#   'negative': 1111,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 466,
#   'average_2weeks': 0,
#   'median_forever': 43,
#   'median_2weeks': 0,
#   'price': '499',
#   'initialprice': '499',
#   'discount': '0',
#   'ccu': 182},
#  '990080': {'appid': 990080,
#   'name': 'Hogwarts Legacy',
#   'developer': 'Avalanche Software',
#   'publisher': 'Warner Bros. Games',
#   'score_rank': '',
#   'positive': 187365,
#   'negative': 16141,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 2408,
#   'average_2weeks': 270,
#   'median_forever': 1946,
#   'median_2weeks': 205,
#   'price': '5999',
#   'initialprice': '5999',
#   'discount': '0',
#   'ccu': 15333},
#  '1938090': {'appid': 1938090,
#   'name': 'Call of Duty: Modern Warfare II',
#   'developer': 'Infinity Ward, Raven Software, Beenox, Treyarch, High Moon Studios, Sledgehammer Games, Activision Shanghai, Demonware, Toys for Bob',
#   'publisher': 'Activision',
#   'score_rank': '',
#   'positive': 228400,
#   'negative': 145867,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 2891,
#   'average_2weeks': 495,
#   'median_forever': 529,
#   'median_2weeks': 235,
#   'price': '6999',
#   'initialprice': '6999',
#   'discount': '0',
#   'ccu': 85500},
#  '386360': {'appid': 386360,
#   'name': 'SMITE',
#   'developer': 'Titan Forge Games',
#   'publisher': 'Hi-Rez Studios',
#   'score_rank': '',
#   'positive': 87057,
#   'negative': 22218,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 5567,
#   'average_2weeks': 865,
#   'median_forever': 217,
#   'median_2weeks': 606,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 15270},
#  '755790': {'appid': 755790,
#   'name': 'Ring of Elysium',
#   'developer': 'Aurora Studio',
#   'publisher': 'TCH Scarlet Limited',
#   'score_rank': '',
#   'positive': 74584,
#   'negative': 25875,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 1357,
#   'average_2weeks': 242,
#   'median_forever': 101,
#   'median_2weeks': 280,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 381},
#  '550650': {'appid': 550650,
#   'name': 'Black Squad',
#   'developer': 'VALOFE, NS STUDIO',
#   'publisher': 'VALOFE',
#   'score_rank': '',
#   'positive': 61016,
#   'negative': 19125,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 2005,
#   'average_2weeks': 805,
#   'median_forever': 66,
#   'median_2weeks': 805,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 1006},
#  '301520': {'appid': 301520,
#   'name': 'Robocraft',
#   'developer': 'Freejam',
#   'publisher': 'Freejam',
#   'score_rank': '',
#   'positive': 86119,
#   'negative': 32311,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 1212,
#   'average_2weeks': 7,
#   'median_forever': 177,
#   'median_2weeks': 7,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 283},
#  '240': {'appid': 240,
#   'name': 'Counter-Strike: Source',
#   'developer': 'Valve',
#   'publisher': 'Valve',
#   'score_rank': '',
#   'positive': 148433,
#   'negative': 5769,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 7075,
#   'average_2weeks': 468,
#   'median_forever': 402,
#   'median_2weeks': 684,
#   'price': '999',
#   'initialprice': '999',
#   'discount': '0',
#   'ccu': 3636},
#  '444200': {'appid': 444200,
#   'name': 'World of Tanks Blitz',
#   'developer': 'Wargaming Group Limited',
#   'publisher': 'Wargaming Group Limited',
#   'score_rank': '',
#   'positive': 103066,
#   'negative': 25338,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 5831,
#   'average_2weeks': 208,
#   'median_forever': 171,
#   'median_2weeks': 239,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 14681},
#  '477160': {'appid': 477160,
#   'name': 'Human: Fall Flat',
#   'developer': 'No Brakes Games',
#   'publisher': 'Curve Games',
#   'score_rank': '',
#   'positive': 173983,
#   'negative': 9687,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 781,
#   'average_2weeks': 440,
#   'median_forever': 368,
#   'median_2weeks': 85,
#   'price': '599',
#   'initialprice': '1999',
#   'discount': '70',
#   'ccu': 5466},
#  '582010': {'appid': 582010,
#   'name': 'Monster Hunter: World',
#   'developer': 'CAPCOM Co., Ltd.',
#   'publisher': 'CAPCOM Co., Ltd.',
#   'score_rank': '',
#   'positive': 329850,
#   'negative': 52508,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 8428,
#   'average_2weeks': 643,
#   'median_forever': 2638,
#   'median_2weeks': 657,
#   'price': '2999',
#   'initialprice': '2999',
#   'discount': '0',
#   'ccu': 23006},
#  '648800': {'appid': 648800,
#   'name': 'Raft',
#   'developer': 'Redbeet Interactive',
#   'publisher': 'Axolot Games',
#   'score_rank': '',
#   'positive': 251038,
#   'negative': 16831,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 1493,
#   'average_2weeks': 336,
#   'median_forever': 873,
#   'median_2weeks': 295,
#   'price': '1999',
#   'initialprice': '1999',
#   'discount': '0',
#   'ccu': 12203},
#  '433850': {'appid': 433850,
#   'name': 'Z1 Battle Royale',
#   'developer': 'Daybreak Game Company',
#   'publisher': 'Daybreak Game Company',
#   'score_rank': '',
#   'positive': 114906,
#   'negative': 91962,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 2791,
#   'average_2weeks': 4376,
#   'median_forever': 137,
#   'median_2weeks': 4376,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 1214},
#  '417910': {'appid': 417910,
#   'name': 'Street Warriors Online',
#   'developer': 'Crazy Rocks Studios',
#   'publisher': 'Crazy Rocks Studios',
#   'score_rank': '',
#   'positive': 962,
#   'negative': 700,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 58,
#   'average_2weeks': 0,
#   'median_forever': 31,
#   'median_2weeks': 0,
#   'price': '199',
#   'initialprice': '199',
#   'discount': '0',
#   'ccu': 0},
#  '304050': {'appid': 304050,
#   'name': 'Trove',
#   'developer': 'gamigo US Inc.',
#   'publisher': 'gamigo US Inc.',
#   'score_rank': '',
#   'positive': 72258,
#   'negative': 17426,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 3361,
#   'average_2weeks': 22,
#   'median_forever': 217,
#   'median_2weeks': 35,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 1670},
#  '261550': {'appid': 261550,
#   'name': 'Mount & Blade II: Bannerlord',
#   'developer': 'TaleWorlds Entertainment',
#   'publisher': 'TaleWorlds Entertainment',
#   'score_rank': '',
#   'positive': 194397,
#   'negative': 27067,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 7462,
#   'average_2weeks': 651,
#   'median_forever': 3999,
#   'median_2weeks': 421,
#   'price': '4999',
#   'initialprice': '4999',
#   'discount': '0',
#   'ccu': 22816},
#  '239140': {'appid': 239140,
#   'name': 'Dying Light',
#   'developer': 'Techland',
#   'publisher': 'Techland',
#   'score_rank': '',
#   'positive': 362536,
#   'negative': 18637,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 2438,
#   'average_2weeks': 451,
#   'median_forever': 1169,
#   'median_2weeks': 194,
#   'price': '2999',
#   'initialprice': '2999',
#   'discount': '0',
#   'ccu': 6678},
#  '400': {'appid': 400,
#   'name': 'Portal',
#   'developer': 'Valve',
#   'publisher': 'Valve',
#   'score_rank': '',
#   'positive': 129460,
#   'negative': 1974,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 294,
#   'average_2weeks': 241,
#   'median_forever': 161,
#   'median_2weeks': 252,
#   'price': '999',
#   'initialprice': '999',
#   'discount': '0',
#   'ccu': 622},
#  '70': {'appid': 70,
#   'name': 'Half-Life',
#   'developer': 'Valve',
#   'publisher': 'Valve',
#   'score_rank': '',
#   'positive': 85029,
#   'negative': 3047,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 759,
#   'average_2weeks': 136,
#   'median_forever': 162,
#   'median_2weeks': 156,
#   'price': '999',
#   'initialprice': '999',
#   'discount': '0',
#   'ccu': 742},
#  '489520': {'appid': 489520,
#   'name': 'Minion Masters',
#   'developer': 'BetaDwarf',
#   'publisher': 'BetaDwarf',
#   'score_rank': '',
#   'positive': 55382,
#   'negative': 5415,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 4025,
#   'average_2weeks': 283,
#   'median_forever': 202,
#   'median_2weeks': 550,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 1179},
#  '367520': {'appid': 367520,
#   'name': 'Hollow Knight',
#   'developer': 'Team Cherry',
#   'publisher': 'Team Cherry',
#   'score_rank': '',
#   'positive': 281274,
#   'negative': 8124,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 1791,
#   'average_2weeks': 288,
#   'median_forever': 587,
#   'median_2weeks': 198,
#   'price': '1499',
#   'initialprice': '1499',
#   'discount': '0',
#   'ccu': 6085},
#  '251570': {'appid': 251570,
#   'name': '7 Days to Die',
#   'developer': 'The Fun Pimps',
#   'publisher': 'The Fun Pimps Entertainment LLC',
#   'score_rank': '',
#   'positive': 227532,
#   'negative': 29630,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 5449,
#   'average_2weeks': 739,
#   'median_forever': 1224,
#   'median_2weeks': 729,
#   'price': '2499',
#   'initialprice': '2499',
#   'discount': '0',
#   'ccu': 26132},
#  '8930': {'appid': 8930,
#   'name': "Sid Meier's Civilization V",
#   'developer': 'Firaxis Games, Aspyr (Mac), Aspyr (Linux)',
#   'publisher': '2K, Aspyr (Mac), Aspyr (Linux)',
#   'score_rank': '',
#   'positive': 184329,
#   'negative': 7391,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 7533,
#   'average_2weeks': 977,
#   'median_forever': 2397,
#   'median_2weeks': 1455,
#   'price': '2999',
#   'initialprice': '2999',
#   'discount': '0',
#   'ccu': 18849},
#  '1517290': {'appid': 1517290,
#   'name': 'Battlefield 2042',
#   'developer': 'DICE',
#   'publisher': 'Electronic Arts',
#   'score_rank': '',
#   'positive': 69787,
#   'negative': 122746,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 3281,
#   'average_2weeks': 434,
#   'median_forever': 1348,
#   'median_2weeks': 237,
#   'price': '1499',
#   'initialprice': '5999',
#   'discount': '75',
#   'ccu': 16574},
#  '532210': {'appid': 532210,
#   'name': 'Life is Strange 2',
#   'developer': 'DONTNOD Entertainment, Feral Interactive (Mac), Feral Interactive (Linux)',
#   'publisher': 'Square Enix, Feral Interactive (Mac), Feral Interactive (Linux)',
#   'score_rank': '',
#   'positive': 24986,
#   'negative': 4366,
#   'userscore': 0,
#   'owners': '10,000,000 .. 20,000,000',
#   'average_forever': 449,
#   'average_2weeks': 0,
#   'median_forever': 217,
#   'median_2weeks': 0,
#   'price': '3196',
#   'initialprice': '3196',
#   'discount': '0',
#   'ccu': 192},
#  '218230': {'appid': 218230,
#   'name': 'PlanetSide 2',
#   'developer': 'Rogue Planet Games',
#   'publisher': 'Daybreak Game Company',
#   'score_rank': '',
#   'positive': 56903,
#   'negative': 12836,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 2219,
#   'average_2weeks': 363,
#   'median_forever': 151,
#   'median_2weeks': 252,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 2865},
#  '1222670': {'appid': 1222670,
#   'name': 'The Sims 4',
#   'developer': 'Maxis',
#   'publisher': 'Electronic Arts',
#   'score_rank': '',
#   'positive': 86294,
#   'negative': 12739,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 1906,
#   'average_2weeks': 184,
#   'median_forever': 257,
#   'median_2weeks': 133,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 37090},
#  '72850': {'appid': 72850,
#   'name': 'The Elder Scrolls V: Skyrim',
#   'developer': 'Bethesda Game Studios',
#   'publisher': 'Bethesda Softworks',
#   'score_rank': '',
#   'positive': 296993,
#   'negative': 16066,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 6683,
#   'average_2weeks': 92,
#   'median_forever': 2907,
#   'median_2weeks': 139,
#   'price': '1999',
#   'initialprice': '1999',
#   'discount': '0',
#   'ccu': 3118},
#  '1174180': {'appid': 1174180,
#   'name': 'Red Dead Redemption 2',
#   'developer': 'Rockstar Games',
#   'publisher': 'Rockstar Games',
#   'score_rank': '',
#   'positive': 366941,
#   'negative': 39540,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 4591,
#   'average_2weeks': 632,
#   'median_forever': 2393,
#   'median_2weeks': 122,
#   'price': '5999',
#   'initialprice': '5999',
#   'discount': '0',
#   'ccu': 30281},
#  '814380': {'appid': 814380,
#   'name': 'Sekiro: Shadows Die Twice - GOTY Edition',
#   'developer': 'FromSoftware',
#   'publisher': 'Activision (Excluding Japan and Asia), FromSoftware (Japan), 方块游戏 (Asia)',
#   'score_rank': '',
#   'positive': 221293,
#   'negative': 10932,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 2576,
#   'average_2weeks': 234,
#   'median_forever': 1726,
#   'median_2weeks': 178,
#   'price': '5999',
#   'initialprice': '5999',
#   'discount': '0',
#   'ccu': 6473},
#  '308600': {'appid': 308600,
#   'name': 'Gene Shift Auto',
#   'developer': 'Nik Nak Studios',
#   'publisher': 'Nik Nak Studios',
#   'score_rank': '',
#   'positive': 1805,
#   'negative': 398,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 1318,
#   'average_2weeks': 0,
#   'median_forever': 310,
#   'median_2weeks': 0,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 12},
#  '255710': {'appid': 255710,
#   'name': 'Cities: Skylines',
#   'developer': 'Colossal Order Ltd.',
#   'publisher': 'Paradox Interactive',
#   'score_rank': '',
#   'positive': 215875,
#   'negative': 15680,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 2872,
#   'average_2weeks': 513,
#   'median_forever': 823,
#   'median_2weeks': 260,
#   'price': '2999',
#   'initialprice': '2999',
#   'discount': '0',
#   'ccu': 28397},
#  '220': {'appid': 220,
#   'name': 'Half-Life 2',
#   'developer': 'Valve',
#   'publisher': 'Valve',
#   'score_rank': '',
#   'positive': 160138,
#   'negative': 4051,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 663,
#   'average_2weeks': 243,
#   'median_forever': 344,
#   'median_2weeks': 319,
#   'price': '999',
#   'initialprice': '999',
#   'discount': '0',
#   'ccu': 968},
#  '130': {'appid': 130,
#   'name': 'Half-Life: Blue Shift',
#   'developer': 'Gearbox Software',
#   'publisher': 'Valve',
#   'score_rank': '',
#   'positive': 12134,
#   'negative': 1103,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 1091,
#   'average_2weeks': 0,
#   'median_forever': 54,
#   'median_2weeks': 0,
#   'price': '499',
#   'initialprice': '499',
#   'discount': '0',
#   'ccu': 53},
#  '96000': {'appid': 96000,
#   'name': 'The Tiny Bang Story',
#   'developer': 'Colibri Games',
#   'publisher': 'Colibri Games',
#   'score_rank': '',
#   'positive': 5357,
#   'negative': 758,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 283,
#   'average_2weeks': 0,
#   'median_forever': 302,
#   'median_2weeks': 0,
#   'price': '499',
#   'initialprice': '499',
#   'discount': '0',
#   'ccu': 14},
#  '275390': {'appid': 275390,
#   'name': 'Guacamelee! Super Turbo Championship Edition',
#   'developer': 'DrinkBox Studios',
#   'publisher': 'DrinkBox Studios',
#   'score_rank': '',
#   'positive': 5719,
#   'negative': 468,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 150,
#   'average_2weeks': 0,
#   'median_forever': 47,
#   'median_2weeks': 0,
#   'price': '1499',
#   'initialprice': '1499',
#   'discount': '0',
#   'ccu': 19},
#  '1089350': {'appid': 1089350,
#   'name': 'NBA 2K20',
#   'developer': 'Visual Concepts',
#   'publisher': '2K',
#   'score_rank': '',
#   'positive': 30468,
#   'negative': 30426,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 8676,
#   'average_2weeks': 6553,
#   'median_forever': 2984,
#   'median_2weeks': 6553,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 863},
#  '108600': {'appid': 108600,
#   'name': 'Project Zomboid',
#   'developer': 'The Indie Stone',
#   'publisher': 'The Indie Stone',
#   'score_rank': '',
#   'positive': 186654,
#   'negative': 12727,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 3146,
#   'average_2weeks': 1126,
#   'median_forever': 728,
#   'median_2weeks': 403,
#   'price': '1999',
#   'initialprice': '1999',
#   'discount': '0',
#   'ccu': 32958},
#  '224260': {'appid': 224260,
#   'name': 'No More Room in Hell',
#   'developer': 'No More Room in Hell Team',
#   'publisher': 'Lever Games',
#   'score_rank': '',
#   'positive': 61202,
#   'negative': 6890,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 616,
#   'average_2weeks': 17,
#   'median_forever': 87,
#   'median_2weeks': 17,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 902},
#  '60': {'appid': 60,
#   'name': 'Ricochet',
#   'developer': 'Valve',
#   'publisher': 'Valve',
#   'score_rank': '',
#   'positive': 4203,
#   'negative': 926,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 3008,
#   'average_2weeks': 0,
#   'median_forever': 4,
#   'median_2weeks': 0,
#   'price': '499',
#   'initialprice': '499',
#   'discount': '0',
#   'ccu': 7},
#  '1203220': {'appid': 1203220,
#   'name': 'NARAKA: BLADEPOINT',
#   'developer': '24 Entertainment',
#   'publisher': 'NetEase Games Global',
#   'score_rank': '',
#   'positive': 117128,
#   'negative': 60246,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 8772,
#   'average_2weeks': 867,
#   'median_forever': 1711,
#   'median_2weeks': 844,
#   'price': '1999',
#   'initialprice': '1999',
#   'discount': '0',
#   'ccu': 73320},
#  '1046930': {'appid': 1046930,
#   'name': 'Dota Underlords',
#   'developer': 'Valve',
#   'publisher': 'Valve',
#   'score_rank': '',
#   'positive': 74164,
#   'negative': 15855,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 3082,
#   'average_2weeks': 179,
#   'median_forever': 344,
#   'median_2weeks': 224,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 2350},
#  '204360': {'appid': 204360,
#   'name': 'Castle Crashers',
#   'developer': 'The Behemoth',
#   'publisher': 'The Behemoth',
#   'score_rank': '',
#   'positive': 95448,
#   'negative': 3691,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 748,
#   'average_2weeks': 14,
#   'median_forever': 300,
#   'median_2weeks': 17,
#   'price': '1499',
#   'initialprice': '1499',
#   'discount': '0',
#   'ccu': 596},
#  '377160': {'appid': 377160,
#   'name': 'Fallout 4',
#   'developer': 'Bethesda Game Studios',
#   'publisher': 'Bethesda Softworks',
#   'score_rank': '',
#   'positive': 253007,
#   'negative': 54500,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 6062,
#   'average_2weeks': 404,
#   'median_forever': 2367,
#   'median_2weeks': 123,
#   'price': '1999',
#   'initialprice': '1999',
#   'discount': '0',
#   'ccu': 17819},
#  '370910': {'appid': 370910,
#   'name': 'Kathy Rain',
#   'developer': 'Clifftop Games',
#   'publisher': 'Raw Fury',
#   'score_rank': '',
#   'positive': 3301,
#   'negative': 273,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 1271,
#   'average_2weeks': 0,
#   'median_forever': 271,
#   'median_2weeks': 0,
#   'price': '999',
#   'initialprice': '999',
#   'discount': '0',
#   'ccu': 4},
#  '289070': {'appid': 289070,
#   'name': 'Sid Meier’s Civilization VI',
#   'developer': 'Firaxis Games, Aspyr (Mac), Aspyr (Linux)',
#   'publisher': '2K, Aspyr (Mac), Aspyr (Linux)',
#   'score_rank': '',
#   'positive': 226907,
#   'negative': 40031,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 5689,
#   'average_2weeks': 674,
#   'median_forever': 1386,
#   'median_2weeks': 311,
#   'price': '599',
#   'initialprice': '5999',
#   'discount': '90',
#   'ccu': 61664},
#  '203160': {'appid': 203160,
#   'name': 'Tomb Raider',
#   'developer': 'Crystal Dynamics, Eidos-Montréal, Feral Interactive (Mac), Nixxes',
#   'publisher': 'Crystal Dynamics, Feral Interactive (Mac)',
#   'score_rank': '',
#   'positive': 213496,
#   'negative': 8523,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 773,
#   'average_2weeks': 126,
#   'median_forever': 449,
#   'median_2weeks': 245,
#   'price': '199',
#   'initialprice': '199',
#   'discount': '0',
#   'ccu': 705},
#  '107410': {'appid': 107410,
#   'name': 'Arma 3',
#   'developer': 'Bohemia Interactive',
#   'publisher': 'Bohemia Interactive',
#   'score_rank': '',
#   'positive': 221570,
#   'negative': 23298,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 13843,
#   'average_2weeks': 296,
#   'median_forever': 1006,
#   'median_2weeks': 264,
#   'price': '2999',
#   'initialprice': '2999',
#   'discount': '0',
#   'ccu': 15725},
#  '466240': {'appid': 466240,
#   'name': 'Deceit',
#   'developer': 'World Makers',
#   'publisher': 'World Makers',
#   'score_rank': '',
#   'positive': 69265,
#   'negative': 18233,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 478,
#   'average_2weeks': 655,
#   'median_forever': 110,
#   'median_2weeks': 1292,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 1345},
#  '250900': {'appid': 250900,
#   'name': 'The Binding of Isaac: Rebirth',
#   'developer': 'Nicalis, Inc., Edmund McMillen',
#   'publisher': 'Nicalis, Inc.',
#   'score_rank': '',
#   'positive': 233939,
#   'negative': 5635,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 11445,
#   'average_2weeks': 976,
#   'median_forever': 4347,
#   'median_2weeks': 305,
#   'price': '1499',
#   'initialprice': '1499',
#   'discount': '0',
#   'ccu': 18234},
#  '278360': {'appid': 278360,
#   'name': 'A Story About My Uncle',
#   'developer': 'Gone North Games',
#   'publisher': 'Coffee Stain Publishing',
#   'score_rank': '',
#   'positive': 25934,
#   'negative': 2312,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 722,
#   'average_2weeks': 0,
#   'median_forever': 220,
#   'median_2weeks': 0,
#   'price': '1499',
#   'initialprice': '1499',
#   'discount': '0',
#   'ccu': 17},
#  '40': {'appid': 40,
#   'name': 'Deathmatch Classic',
#   'developer': 'Valve',
#   'publisher': 'Valve',
#   'score_rank': '',
#   'positive': 2164,
#   'negative': 479,
#   'userscore': 0,
#   'owners': '5,000,000 .. 10,000,000',
#   'average_forever': 1750,
#   'average_2weeks': 0,
#   'median_forever': 21,
#   'median_2weeks': 0,
#   'price': '499',
#   'initialprice': '499',
#   'discount': '0',
#   'ccu': 9}}

# %%
type(data)
# Out:
# dict

# %%
data.keys()
# Out:
# dict_keys(['570', '1172470', '730', '578080', '1063730', '440', '271590', '1599340', '550', '304930', '252490', '230410', '105600', '4000', '1245620', '236390', '291550', '359550', '340', '431960', '1085660', '945360', '238960', '218620', '892970', '901583', '1091500', '1097150', '242760', '322330', '444090', '291480', '346110', '413150', '49520', '10', '272060', '292030', '438100', '381210', '227940', '1240440', '227300', '252950', '1468810', '620', '552990', '739630', '320', '990080', '1938090', '386360', '755790', '550650', '301520', '240', '444200', '477160', '582010', '648800', '433850', '417910', '304050', '261550', '239140', '400', '70', '489520', '367520', '251570', '8930', '1517290', '532210', '218230', '1222670', '72850', '1174180', '814380', '308600', '255710', '220', '130', '96000', '275390', '1089350', '108600', '224260', '60', '1203220', '1046930', '204360', '377160', '370910', '289070', '203160', '107410', '466240', '250900', '278360', '40'])

# %%
type(data.keys())
# Out:
# dict_keys

# %%
list(data.keys())
# Out:
# ['570',
#  '1172470',
#  '730',
#  '578080',
#  '1063730',
#  '440',
#  '271590',
#  '1599340',
#  '550',
#  '304930',
#  '252490',
#  '230410',
#  '105600',
#  '4000',
#  '1245620',
#  '236390',
#  '291550',
#  '359550',
#  '340',
#  '431960',
#  '1085660',
#  '945360',
#  '238960',
#  '218620',
#  '892970',
#  '901583',
#  '1091500',
#  '1097150',
#  '242760',
#  '322330',
#  '444090',
#  '291480',
#  '346110',
#  '413150',
#  '49520',
#  '10',
#  '272060',
#  '292030',
#  '438100',
#  '381210',
#  '227940',
#  '1240440',
#  '227300',
#  '252950',
#  '1468810',
#  '620',
#  '552990',
#  '739630',
#  '320',
#  '990080',
#  '1938090',
#  '386360',
#  '755790',
#  '550650',
#  '301520',
#  '240',
#  '444200',
#  '477160',
#  '582010',
#  '648800',
#  '433850',
#  '417910',
#  '304050',
#  '261550',
#  '239140',
#  '400',
#  '70',
#  '489520',
#  '367520',
#  '251570',
#  '8930',
#  '1517290',
#  '532210',
#  '218230',
#  '1222670',
#  '72850',
#  '1174180',
#  '814380',
#  '308600',
#  '255710',
#  '220',
#  '130',
#  '96000',
#  '275390',
#  '1089350',
#  '108600',
#  '224260',
#  '60',
#  '1203220',
#  '1046930',
#  '204360',
#  '377160',
#  '370910',
#  '289070',
#  '203160',
#  '107410',
#  '466240',
#  '250900',
#  '278360',
#  '40']

# %%
import steamspypi

data_request = dict()
data_request['request'] = 'all'
data_request['page'] = '0'

data = steamspypi.download(data_request)

#need to space out requests for multiple pages by a minute

# %%
data.keys()
# Out:
# dict_keys(['570', '1172470', '730', '578080', '1063730', '440', '271590', '1599340', '550', '304930', '252490', '230410', '105600', '4000', '1245620', '236390', '291550', '359550', '340', '431960', '1085660', '945360', '238960', '218620', '892970', '901583', '1091500', '1097150', '242760', '322330', '444090', '291480', '346110', '413150', '49520', '10', '272060', '292030', '438100', '381210', '227940', '1240440', '227300', '252950', '1468810', '620', '552990', '739630', '320', '990080', '1938090', '386360', '755790', '550650', '301520', '240', '444200', '477160', '582010', '648800', '433850', '417910', '304050', '261550', '239140', '400', '70', '489520', '367520', '251570', '8930', '1517290', '532210', '218230', '1222670', '72850', '1174180', '814380', '308600', '255710', '220', '130', '96000', '275390', '1089350', '108600', '224260', '60', '1203220', '1046930', '204360', '377160', '370910', '289070', '203160', '107410', '466240', '250900', '278360', '40', '333930', '632360', '1811260', '275850', '221100', '588430', '219990', '374320', '360', '365590', '10180', '1326470', '489830', '387990', '427520', '439700', '322170', '273350', '582660', '844870', '700330', '2630', '394360', '976730', '1172620', '285800', '363970', '219640', '253710', '594570', '813820', '311210', '883710', '22380', '1238810', '30', '319630', '221380', '1604030', '594650', '12120', '109600', '20', '1407200', '242050', '238460', '268500', '231430', '225840', '863550', '306130', '1286830', '555570', '8870', '1145360', '1794680', '435150', '1100600', '273110', '223470', '677620', '346900', '233450', '1818750', '12210', '420', '365670', '300', '629760', '1426210', '241930', '264710', '208090', '397900', '304390', '113400', '588650', '601150', '339610', '8980', '211500', '526870', '379720', '50', '500', '206420', '3590', '238320', '252130', '424840', '223710', '646570', '1250', '284160', '552500', '48700', '534380', '39210', '268910', '15700', '356190', '779340', '211820', '782330', '55230', '868270', '8190', '236850', '391540', '42910', '513710', '355840', '294100', '630', '6060', '225540', '1593500', '57300', '504370', '20920', '222880', '55150', '200210', '262060', '407530', '286160', '899770', '1118200', '33930', '24240', '1056960', '1332010', '391220', '466560', '395170', '223750', '232090', '1049590', '115300', '386180', '220240', '871720', '244210', '1225330', '63380', '1366540', '1506830', '744900', '508440', '8500', '212500', '202970', '302830', '7670', '1237970', '244850', '761890', '281990', '48000', '620980', '201270', '1551360', '674940', '506540', '440900', '200710', '813780', '884660', '205100', '35450', '601510', '380600', '1446780', '311690', '261640', '397540', '312990', '234140', '9480', '518790', '960090', '1832640', '1293830', '203770', '20900', '548430', '698780', '1238840', '209080', '546560', '232770', '99900', '214950', '220200', '380', '299360', '10090', '265630', '224600', '202990', '35720', '200510', '389730', '1196590', '335240', '2050650', '236870', '4560', '280', '50130', '270880', '219740', '323190', '355180', '212680', '1172380', '208650', '207610', '233130', '17410', '1151340', '457140', '475150', '359320', '368230', '219150', '203140', '409710', '728880', '962130', '918570', '247080', '312660', '307780', '209870', '880940', '391720', '12100', '113200', '282440', '766570', '617290', '1180380', '1289310', '1057090', '1263850', '678950', '1677740', '213670', '242720', '282070', '24200', '1721470', '1222680', '279720', '33230', '905370', '286940', '1142710', '582160', '8850', '262410', '316010', '286690', '1619450', '361420', '239030', '386940', '387290', '845070', '265930', '65800', '253980', '39120', '838350', '438740', '379430', '287390', '362890', '1158310', '246620', '364360', '335300', '11020', '550900', '107100', '286570', '207140', '530700', '304430', '203290', '644560', '403640', '214490', '460930', '298110', '976310', '38400', '55100', '331470', '24960', '418370', '221910', '992300', '1086940', '201790', '211420', '105664 ...

# %%
import pickle

with open('top1000games_may29_347pm.pkl', 'wb') as fp:
    pickle.dump(list(data.keys()), fp)

# %%
list(data.keys())
# Out:
# ['570',
#  '1172470',
#  '730',
#  '578080',
#  '1063730',
#  '440',
#  '271590',
#  '1599340',
#  '550',
#  '304930',
#  '252490',
#  '230410',
#  '105600',
#  '4000',
#  '1245620',
#  '236390',
#  '291550',
#  '359550',
#  '340',
#  '431960',
#  '1085660',
#  '945360',
#  '238960',
#  '218620',
#  '892970',
#  '901583',
#  '1091500',
#  '1097150',
#  '242760',
#  '322330',
#  '444090',
#  '291480',
#  '346110',
#  '413150',
#  '49520',
#  '10',
#  '272060',
#  '292030',
#  '438100',
#  '381210',
#  '227940',
#  '1240440',
#  '227300',
#  '252950',
#  '1468810',
#  '620',
#  '552990',
#  '739630',
#  '320',
#  '990080',
#  '1938090',
#  '386360',
#  '755790',
#  '550650',
#  '301520',
#  '240',
#  '444200',
#  '477160',
#  '582010',
#  '648800',
#  '433850',
#  '417910',
#  '304050',
#  '261550',
#  '239140',
#  '400',
#  '70',
#  '489520',
#  '367520',
#  '251570',
#  '8930',
#  '1517290',
#  '532210',
#  '218230',
#  '1222670',
#  '72850',
#  '1174180',
#  '814380',
#  '308600',
#  '255710',
#  '220',
#  '130',
#  '96000',
#  '275390',
#  '1089350',
#  '108600',
#  '224260',
#  '60',
#  '1203220',
#  '1046930',
#  '204360',
#  '377160',
#  '370910',
#  '289070',
#  '203160',
#  '107410',
#  '466240',
#  '250900',
#  '278360',
#  '40',
#  '333930',
#  '632360',
#  '1811260',
#  '275850',
#  '221100',
#  '588430',
#  '219990',
#  '374320',
#  '360',
#  '365590',
#  '10180',
#  '1326470',
#  '489830',
#  '387990',
#  '427520',
#  '439700',
#  '322170',
#  '273350',
#  '582660',
#  '844870',
#  '700330',
#  '2630',
#  '394360',
#  '976730',
#  '1172620',
#  '285800',
#  '363970',
#  '219640',
#  '253710',
#  '594570',
#  '813820',
#  '311210',
#  '883710',
#  '22380',
#  '1238810',
#  '30',
#  '319630',
#  '221380',
#  '1604030',
#  '594650',
#  '12120',
#  '109600',
