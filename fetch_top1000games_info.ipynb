# %%
import steamspypi

data_request = dict()
data_request['request'] = 'all'
data_request['page'] = '0'

data = steamspypi.download(data_request)

#need to space out requests for multiple pages by a minute

# %%
data
# Out:
# {'570': {'appid': 570,
#   'name': 'Dota 2',
#   'developer': 'Valve',
#   'publisher': 'Valve',
#   'score_rank': '',
#   'positive': 1639582,
#   'negative': 349743,
#   'userscore': 0,
#   'owners': '200,000,000 .. 500,000,000',
#   'average_forever': 38664,
#   'average_2weeks': 1644,
#   'median_forever': 850,
#   'median_2weeks': 870,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 609892},
#  '1172470': {'appid': 1172470,
#   'name': 'Apex Legends',
#   'developer': 'Respawn Entertainment',
#   'publisher': 'Electronic Arts',
#   'score_rank': '',
#   'positive': 539737,
#   'negative': 120787,
#   'userscore': 0,
#   'owners': '50,000,000 .. 100,000,000',
#   'average_forever': 7964,
#   'average_2weeks': 743,
#   'median_forever': 806,
#   'median_2weeks': 330,
#   'price': '0',
#   'initialprice': '0',
#   'discount': '0',
#   'ccu': 365767},
#  '730': {'appid': 730,
#   'name': 'Counter-Strike: Global Offensive',
# ...

# %%
import pickle

with open('top1000games_may29_347pm.pkl', 'wb') as fp:
    pickle.dump(list(data), fp)
